# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaish9602/PRODIGY_TASKS/blob/main/PRODIGY_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task -1**

# %% [markdown]
# Analyze traffic accident data to identify patterns related to road conditions, weather, and time of day. Visualize accident hotspots and contributing factors.

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/reasonOfAccident.csv")

# %%
df
# Out:
#     Sl. No             States/UTs  \
# 0        1         Andhra Pradesh
# 1        2      Arunachal Pradesh
# 2        3                  Assam
# 3        4                  Bihar
# 4        5           Chhattisgarh
# 5        6                    Goa
# 6        7                Gujarat
# 7        8                Haryana
# 8        9       Himachal Pradesh
# 9       10        Jammu & Kashmir
# 10      11              Jharkhand
# 11      12              Karnataka
# 12      13                 Kerala
# 13      14         Madhya Pradesh
# 14      15            Maharashtra
# 15      16                Manipur
# 16      17              Meghalaya
# 17      18                Mizoram
# 18      19               Nagaland
# 19      20                 Odisha
# 20      21                 Punjab
# 21      22              Rajasthan
# 22      23                 Sikkim
# 23      24             Tamil Nadu
# 24      25              Telangana
# 25      26                Tripura
# ...

# %%
df.head(10)
# Out:
#   Sl. No         States/UTs  \
# 0      1     Andhra Pradesh
# 1      2  Arunachal Pradesh
# 2      3              Assam
# 3      4              Bihar
# 4      5       Chhattisgarh
# 5      6                Goa
# 6      7            Gujarat
# 7      8            Haryana
# 8      9   Himachal Pradesh
# 9     10    Jammu & Kashmir
#
#    Fault of Driver-Total No. of Road Accidents - 2014  \
# 0                                            21359.0
# 1                                               30.0
# 2                                             6895.0
# 3                                             5008.0
# 4                                             9108.0
# 5                                             3795.0
# 6                                            18945.0
# 7                                             8208.0
# 8                                             2936.0
# 9                                             3614.0
#
# ...

# %%
# Checking the columns in the data
df.columns
# Out:
# Index(['Sl. No', 'States/UTs',
#        'Fault of Driver-Total No. of Road Accidents - 2014',
#        'Fault of Driver-Total No. of Road Accidents - 2014 per 1L people',
#        'Fault of Driver-Number of Persons-Killed - 2014',
#        'Fault of Driver-Number of Persons-Killed - 2014 per 1L people',
#        'Fault of Driver-Number of Persons-Injured - 2014',
#        'Fault of Driver-Number of Persons-Injured - 2014 per 1L people',
#        'Fault of Driver of other vehicles-Total No. of Road Accidents - 2014',
#        'Fault of Driver of other vehicles-Total No. of Road Accidents - 2014 per 1L people',
#        'Fault of Driver of other vehicles-Number of Persons-Killed - 2014',
#        'Fault of Driver of other vehicles-Number of Persons-Killed - 2014 per 1L people',
#        'Fault of Driver of other vehicles-Number of Persons-Injured - 2014',
#        'Fault of Driver of other vehicles-Number of Persons-Injured - 2014 per 1L people',
# ...

# %%
print("Number of columns: ",len(df.columns))
print("Number of rows: ",len(df))
# Out:
# Number of columns:  63
# Number of rows:  37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 63 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   Sl. No                                                                                 37 non-null     object
#  1   States/UTs                                                                             37 non-null     object
#  2   Fault of Driver-Total No. of Road Accidents - 2014                                     36 non-null     float64
#  3   Fault of Driver-Total No. of Road Accidents - 2014 per 1L people                       36 non-null     float64
#  4   Fault of Driver-Number of Persons-Killed - 2014                                        37 non-null     int64
# ...

# %%
df.describe()
# Out:
#        Fault of Driver-Total No. of Road Accidents - 2014  \
# count                                          36.000000
# mean                                        21055.111111
# std                                         63363.244239
# min                                             0.000000
# 25%                                           216.250000
# 50%                                          3822.000000
# 75%                                         16994.250000
# max                                        378992.000000
#
#        Fault of Driver-Total No. of Road Accidents - 2014 per 1L people  \
# count                                          36.000000
# mean                                           36.666151
# std                                            46.435355
# min                                             0.000000
# 25%                                            10.367798
# 50%                                            27.064447
# ...

# %%
len(df.select_dtypes(['int64', 'float64']).columns)
# Out:
# 60

# %%
df.isnull().sum()
# Out:
# Sl. No                                                                          0
# States/UTs                                                                      0
# Fault of Driver-Total No. of Road Accidents - 2014                              1
# Fault of Driver-Total No. of Road Accidents - 2014 per 1L people                1
# Fault of Driver-Number of Persons-Killed - 2014                                 0
#                                                                                ..
# Other causes/causes not known-Number of Persons-Killed - 2014                   0
# Other causes/causes not known-Number of Persons-Killed - 2014 per 1L people     0
# Other causes/causes not known-Number of Persons-Injured - 2014                  1
# Other causes/causes not known-Number of Persons-Injured - 2014 per 1L people    1
# Population                                                                      0
# Length: 63, dtype: int64

# %%
df.isna().sum()
# Out:
# Sl. No                                                                          0
# States/UTs                                                                      0
# Fault of Driver-Total No. of Road Accidents - 2014                              1
# Fault of Driver-Total No. of Road Accidents - 2014 per 1L people                1
# Fault of Driver-Number of Persons-Killed - 2014                                 0
#                                                                                ..
# Other causes/causes not known-Number of Persons-Killed - 2014                   0
# Other causes/causes not known-Number of Persons-Killed - 2014 per 1L people     0
# Other causes/causes not known-Number of Persons-Injured - 2014                  1
# Other causes/causes not known-Number of Persons-Injured - 2014 per 1L people    1
# Population                                                                      0
# Length: 63, dtype: int64

# %%
df.isna().sum().sort_values(ascending=False) * 100. / len(df)
# Out:
# Defect in Road Condition-Number of Persons-Injured - 2014 per 1L people                2.702703
# Falling of boulders-Total No. of Road Accidents - 2014                                 2.702703
# Defect in Condition of Motor Vehicle-Number of Persons-Injured - 2014                  2.702703
# Defect in Condition of Motor Vehicle-Number of Persons-Injured - 2014 per 1L people    2.702703
# Defect in Road Condition-Total No. of Road Accidents - 2014                            2.702703
#                                                                                          ...
# Fault of Driver of other vehicles-Number of Persons-Killed - 2014 per 1L people        0.000000
# Fault of Driver of other vehicles-Number of Persons-Killed - 2014                      0.000000
# Fault of Driver-Number of Persons-Killed - 2014 per 1L people                          0.000000
# Fault of Driver-Number of Persons-Killed - 2014                                        0.000000
# ...

# %%
# Plotting a Pandas.Series data
missing_data = df.isna().sum().sort_values(ascending=False) * 100. / len(df)

# %%
type(missing_data)
# Out:
# pandas.core.series.Series

# %%
missing_data.plot(kind='bar')
# Out:
# <Axes: >

# %%
missing_data[missing_data!=0].plot(kind='barh')
# Out:
# <Axes: >

# %%
# Printing all the columns
df.columns
# Out:
# Index(['Sl. No', 'States/UTs',
#        'Fault of Driver-Total No. of Road Accidents - 2014',
#        'Fault of Driver-Total No. of Road Accidents - 2014 per 1L people',
#        'Fault of Driver-Number of Persons-Killed - 2014',
#        'Fault of Driver-Number of Persons-Killed - 2014 per 1L people',
#        'Fault of Driver-Number of Persons-Injured - 2014',
#        'Fault of Driver-Number of Persons-Injured - 2014 per 1L people',
#        'Fault of Driver of other vehicles-Total No. of Road Accidents - 2014',
#        'Fault of Driver of other vehicles-Total No. of Road Accidents - 2014 per 1L people',
#        'Fault of Driver of other vehicles-Number of Persons-Killed - 2014',
#        'Fault of Driver of other vehicles-Number of Persons-Killed - 2014 per 1L people',
#        'Fault of Driver of other vehicles-Number of Persons-Injured - 2014',
#        'Fault of Driver of other vehicles-Number of Persons-Injured - 2014 per 1L people',
# ...
